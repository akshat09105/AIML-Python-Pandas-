# %% [markdown]
# <a href="https://colab.research.google.com/github/akshat09105/AIML-Python-Pandas-/blob/main/Working__with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# 1.working with **Series**

# %% [markdown]
# 1.1 Create a series using list

# %%
L=[1,2,3,4,5]
pd.Series(L)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# 1.2 A series has been created with data along with it's Index

# %%
a1=[1,2,3,4,5,6]
a2=['a','b','c','d','e','f']
a3=pd.Series(a1,a2)
print(a3)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# dtype: int64

# %% [markdown]
# Access the data in series

# %%
print(a3['a'])
# Out:
# 1

# %% [markdown]
# 1.3 Creating a series using dictionary

# %%
A={'a':1,'b':2,'c':3,'d':4}
b=pd.Series(A)
print(b,type(b))
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# 1.4 Creating a series using nested list

# %%
d1=[[1,2,3],[4,5,6]]
pd.Series(d1)
# Out:
# 0    [1, 2, 3]
# 1    [4, 5, 6]
# dtype: object

# %% [markdown]
# 2. DataFrames
#
# *   DataFrames are 2 dimensional data structure which has rows and columns.

# %% [markdown]
# 2.1 Creating a data frame using dictionary

# %%
d={'A':[1,2,3,4],'B':[5,6,7,8],'C':[9,10,11,12],'D':[13,14,15,16]}
print(pd.DataFrame(d))
# Out:
#    A  B   C   D
# 0  1  5   9  13
# 1  2  6  10  14
# 2  3  7  11  15
# 3  4  8  12  16

# %% [markdown]
# 2.2 Creating a data frame using nested list & 2.3 Assigning indexes within a data frame

# %%
d=[[1,2],[3,4]]
d2=pd.DataFrame(d,columns=['A','B'],index=[1,2])
d2
# Out:
#    A  B
# 1  1  2
# 2  3  4

# %% [markdown]
# 2.4 Creating data frame using list of dictionaries

# %%
D=[{'A':1,'B':2,'C':3},{'A':4,'B':5,'C':6}]
pd.DataFrame(D)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %% [markdown]
# 2.5 Creating random data frame

# %%
import random as r
import string as s
import pandas as pd
d={'A':[r.randint(1,9) for x in range(5)],
   'B':[r.randint(1,9)*10 for x in range(5)],
   'C':[r.randint(1,9)*100 for x in range(5)],
   'D':["".join(r.sample(s.ascii_letters,6)) for x in range(5)],
   'E':1}
df=pd.DataFrame(d)
df
# Out:
#    A   B    C       D  E
# 0  7  60  100  eObpHY  1
# 1  7  10  200  fdgLIz  1
# 2  1  80  600  miQMlv  1
# 3  7  50  500  kUdczK  1
# 4  6  10  400  JLRgbQ  1

# %% [markdown]
# 2.6 Describe the data frame

# %%
df.describe()
# Out:
#               A          B           C    E
# count  5.000000   5.000000    5.000000  5.0
# mean   5.600000  42.000000  360.000000  1.0
# std    2.607681  31.144823  207.364414  0.0
# min    1.000000  10.000000  100.000000  1.0
# 25%    6.000000  10.000000  200.000000  1.0
# 50%    7.000000  50.000000  400.000000  1.0
# 75%    7.000000  60.000000  500.000000  1.0
# max    7.000000  80.000000  600.000000  1.0

# %% [markdown]
# 2.7 Date as index

# %%
date=pd.date_range('230101',periods=5)
df=pd.DataFrame(d,index=date)
ff=df
df
# Out:
#             A   B    C       D  E
# 2001-01-23  7  60  100  eObpHY  1
# 2001-01-24  7  10  200  fdgLIz  1
# 2001-01-25  1  80  600  miQMlv  1
# 2001-01-26  7  50  500  kUdczK  1
# 2001-01-27  6  10  400  JLRgbQ  1

# %% [markdown]
# 2.8 List the column names

# %%
df.index.name='Date'
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df
# Out:
#             A   B    C       D  E
# Date
# 2001-01-23  7  60  100  eObpHY  1
# 2001-01-24  7  10  200  fdgLIz  1
# 2001-01-25  1  80  600  miQMlv  1
# 2001-01-26  7  50  500  kUdczK  1
# 2001-01-27  6  10  400  JLRgbQ  1

# %% [markdown]
# 2.9 List the index names

# %%
df.index
# Out:
# DatetimeIndex(['2001-01-23', '2001-01-24', '2001-01-25', '2001-01-26',
#                '2001-01-27'],
#               dtype='datetime64[ns]', name='Date', freq='D')

# %% [markdown]
# 2.10 Sorting by an axis

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#             E       D    C   B  A
# Date
# 2001-01-23  1  eObpHY  100  60  7
# 2001-01-24  1  fdgLIz  200  10  7
# 2001-01-25  1  miQMlv  600  80  1
# 2001-01-26  1  kUdczK  500  50  7
# 2001-01-27  1  JLRgbQ  400  10  6

# %% [markdown]
# 2.11 Sorting wrt to row name

# %%
df.sort_index()
# Out:
#                    A         B         C         D
# Date
# 2001-01-23  0.908653 -0.346724 -0.875243  0.862151
# 2001-01-24  2.310985  1.882591  0.410556 -0.850591
# 2001-01-25 -1.459983  0.355408 -0.544485  0.307343
# 2001-01-26  1.044368 -0.431689 -0.545804  1.265403
# 2001-01-27 -0.836866 -0.397439 -0.533983  0.034197

# %%
import numpy as np
df=pd.DataFrame(np.random.randn(5,4),index=date,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# Date
# 2001-01-23  0.908653 -0.346724 -0.875243  0.862151
# 2001-01-24  2.310985  1.882591  0.410556 -0.850591
# 2001-01-25 -1.459983  0.355408 -0.544485  0.307343
# 2001-01-26  1.044368 -0.431689 -0.545804  1.265403
# 2001-01-27 -0.836866 -0.397439 -0.533983  0.034197

# %% [markdown]
# 2.12 Selecting Data

# %%
df[df>0]
# Out:
#                    A         B         C         D
# Date
# 2001-01-23  0.908653       NaN       NaN  0.862151
# 2001-01-24  2.310985  1.882591  0.410556       NaN
# 2001-01-25       NaN  0.355408       NaN  0.307343
# 2001-01-26  1.044368       NaN       NaN  1.265403
# 2001-01-27       NaN       NaN       NaN  0.034197

# %% [markdown]
# ---
# Example 2

# %%
df[df['A']>0]
# Out:
#                    A         B         C         D
# Date
# 2001-01-23  0.908653 -0.346724 -0.875243  0.862151
# 2001-01-24  2.310985  1.882591  0.410556 -0.850591
# 2001-01-26  1.044368 -0.431689 -0.545804  1.265403

# %% [markdown]
# ---
# # **3. Operations on DataFrames**
# - Select
# - Append
# - Concatinate
# - Join
# - Merge
#
# ---
# ### **3.1 Accessing data from data frame - Part 1**
#
# - **Syntax**
#   - #### df [ Row] [ Col ]
#   - #### df [ Row_Range ] [ Col_Names_in_List ]
# ---

# %%
# Un-comment each row and run

df                       # Show all records
df[:]                    # Show all records
df[1:4]                  # Show 1,2,3 rows of all Columns
df[:]['A']               # Show all rows of Column A
#df[:]['A','B']           # Error; Column names must be in the list
df[:][['A','B']]         # Show all rows of Column A, B
df[1:3][['A','B','C']]   # Show 1,2 rows of Column A, B, C
# Out:
#                    A         B         C
# Date
# 2001-01-24  2.310985  1.882591  0.410556
# 2001-01-25 -1.459983  0.355408 -0.544485

# %% [markdown]
# 3.3 Accessing data from data frame using column index (using iloc) - Part 3

# %%
# Un-comment each row and run
df.iloc[:]
#df.iloc[,]                    # Error
df.iloc[:,]                   # Show all rows of all columns
#df.iloc[:,1,2,3]              # Error
df.iloc[:,[1,2,3]]            # Show all rows of 1, 2, 3 columns
df.iloc[2:,]                  # Show rows from 2 to end of all columns
df.iloc[2:, [0,1,3]]          # Show rows from 2 to end of 0, 1, 3 columns
df.iloc[1:3, ]                # Show rows from 1 to 3 of all columns
#df.iloc[1:3, [0,1]]           # Show rows from 1 to 3 of 0, 1 columns
df.iloc[1:3, 1:5]             # Show rows from 1 to 3 of 1-4 columns
df.iloc[1:3, :5]              # Show rows from 1 to 3 of 0-4 columns
df.iloc[1:3, :-2]             # Show rows from 1 to 3 of 0 to 2nd last columns
df.iloc[:-2, 1:3]             # Show rows from 0 to 2nd last of 1-2 columns
# Out:
#                    B         C
# Date
# 2001-01-23 -0.346724 -0.875243
# 2001-01-24  1.882591  0.410556
# 2001-01-25  0.355408 -0.544485

# %% [markdown]
# 3.4 Concatenate data frames

# %%
df1=pd.DataFrame(np.random.randn(4,5),columns=list('ABCDE'))
print(df1)
df2=pd.DataFrame(np.random.randn(5,6),columns=list('ABCDEF'))
print(df2)
# Out:
#           A         B         C         D         E
# 0  0.098759 -0.810400 -1.385385  1.173777  0.863789
# 1  0.243880 -1.073587  0.000426  2.137543 -1.443308
# 2  0.270941 -0.703800 -1.444745 -0.991683 -1.627694
# 3  0.479547 -0.672120 -0.805180 -0.121604 -0.211399
#           A         B         C         D         E         F
# 0  0.546617 -1.150689 -0.092514 -1.008095  0.434155  0.314628
# 1  1.434703 -0.002986  0.536616  0.758455  0.555557  0.780170
# 2  0.634625  1.021615  0.407903 -0.420433 -0.160693 -0.264144
# 3  0.841125 -0.007757 -0.214978  1.776889 -0.011429  0.424934
# 4 -0.464454  1.657431  1.155274 -0.518068 -0.435226  0.958485

# %% [markdown]
# by row wise

# %%
#now converging df1 and df2
df3=pd.concat([df1,df2],axis=0)
df3
# Out:
#           A         B         C         D         E         F
# 0  0.098759 -0.810400 -1.385385  1.173777  0.863789       NaN
# 1  0.243880 -1.073587  0.000426  2.137543 -1.443308       NaN
# 2  0.270941 -0.703800 -1.444745 -0.991683 -1.627694       NaN
# 3  0.479547 -0.672120 -0.805180 -0.121604 -0.211399       NaN
# 0  0.546617 -1.150689 -0.092514 -1.008095  0.434155  0.314628
# 1  1.434703 -0.002986  0.536616  0.758455  0.555557  0.780170
# 2  0.634625  1.021615  0.407903 -0.420433 -0.160693 -0.264144
# 3  0.841125 -0.007757 -0.214978  1.776889 -0.011429  0.424934
# 4 -0.464454  1.657431  1.155274 -0.518068 -0.435226  0.958485

# %% [markdown]
# by column wise

# %%
df3=pd.concat([df1,df2],axis=1)
df3
# Out:
#           A         B         C         D         E         A         B  \
# 0  0.098759 -0.810400 -1.385385  1.173777  0.863789  0.546617 -1.150689
# 1  0.243880 -1.073587  0.000426  2.137543 -1.443308  1.434703 -0.002986
# 2  0.270941 -0.703800 -1.444745 -0.991683 -1.627694  0.634625  1.021615
# 3  0.479547 -0.672120 -0.805180 -0.121604 -0.211399  0.841125 -0.007757
# 4       NaN       NaN       NaN       NaN       NaN -0.464454  1.657431
#
#           C         D         E         F
# 0 -0.092514 -1.008095  0.434155  0.314628
# 1  0.536616  0.758455  0.555557  0.780170
# 2  0.407903 -0.420433 -0.160693 -0.264144
# 3 -0.214978  1.776889 -0.011429  0.424934
# 4  1.155274 -0.518068 -0.435226  0.958485

# %% [markdown]
# Change index using reset_index()

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#           A         B         C         D
# 0  0.908653 -0.346724 -0.875243  0.862151
# 1  2.310985  1.882591  0.410556 -0.850591
# 2 -1.459983  0.355408 -0.544485  0.307343
# 3  1.044368 -0.431689 -0.545804  1.265403
# 4 -0.836866 -0.397439 -0.533983  0.034197

# %% [markdown]
# ignore_index=True

# %%
df3=pd.concat([df1,df2],ignore_index=True)
df3
# Out:
#           A         B         C         D         E         F
# 0  0.098759 -0.810400 -1.385385  1.173777  0.863789       NaN
# 1  0.243880 -1.073587  0.000426  2.137543 -1.443308       NaN
# 2  0.270941 -0.703800 -1.444745 -0.991683 -1.627694       NaN
# 3  0.479547 -0.672120 -0.805180 -0.121604 -0.211399       NaN
# 4  0.546617 -1.150689 -0.092514 -1.008095  0.434155  0.314628
# 5  1.434703 -0.002986  0.536616  0.758455  0.555557  0.780170
# 6  0.634625  1.021615  0.407903 -0.420433 -0.160693 -0.264144
# 7  0.841125 -0.007757 -0.214978  1.776889 -0.011429  0.424934
# 8 -0.464454  1.657431  1.155274 -0.518068 -0.435226  0.958485

# %% [markdown]
# 3.5 Shuffle data frames (row wise)

# %%
df3.sample(frac=1)
# Out:
#           A         B         C         D         E         F
# 3  0.479547 -0.672120 -0.805180 -0.121604 -0.211399       NaN
# 7  0.841125 -0.007757 -0.214978  1.776889 -0.011429  0.424934
# 1  0.243880 -1.073587  0.000426  2.137543 -1.443308       NaN
# 5  1.434703 -0.002986  0.536616  0.758455  0.555557  0.780170
# 0  0.098759 -0.810400 -1.385385  1.173777  0.863789       NaN
# 2  0.270941 -0.703800 -1.444745 -0.991683 -1.627694       NaN
# 6  0.634625  1.021615  0.407903 -0.420433 -0.160693 -0.264144
# 4  0.546617 -1.150689 -0.092514 -1.008095  0.434155  0.314628
# 8 -0.464454  1.657431  1.155274 -0.518068 -0.435226  0.958485

# %% [markdown]
# 3.6 Concatenate data frames using join = 'inner' (intersection)

# %%
df1=pd.DataFrame(np.random.randn(6,5))
print(df1)
df2=pd.DataFrame(np.random.randn(5,4))
print(df2)
# Out:
#           0         1         2         3         4
# 0 -0.626788  1.565946 -0.252991 -0.131553 -1.578725
# 1 -0.466376 -0.744839 -0.409002 -0.704478 -0.708386
# 2  1.434732  0.799465 -0.209512  0.594617  0.528272
# 3 -0.589754  0.029569 -1.314295  1.194373  1.295154
# 4  0.608282  1.125297  0.669932 -0.192409  1.088963
# 5  0.097562  0.973448 -0.501081 -2.382428  0.143134
#           0         1         2         3
# 0  0.544465 -0.086178 -0.884574  0.962751
# 1 -1.331185  0.556176  1.441838  1.739134
# 2  1.408658  1.161387  0.980376 -0.623762
# 3 -0.133570  0.261933  1.387955  0.285104
# 4  1.194254  0.125874 -0.320275 -0.464618

# %% [markdown]
# Along column

# %%
df3=pd.concat([df1,df2],axis=0,join="inner")
df3
# Out:
#           0         1         2         3
# 0 -0.626788  1.565946 -0.252991 -0.131553
# 1 -0.466376 -0.744839 -0.409002 -0.704478
# 2  1.434732  0.799465 -0.209512  0.594617
# 3 -0.589754  0.029569 -1.314295  1.194373
# 4  0.608282  1.125297  0.669932 -0.192409
# 5  0.097562  0.973448 -0.501081 -2.382428
# 0  0.544465 -0.086178 -0.884574  0.962751
# 1 -1.331185  0.556176  1.441838  1.739134
# 2  1.408658  1.161387  0.980376 -0.623762
# 3 -0.133570  0.261933  1.387955  0.285104
# 4  1.194254  0.125874 -0.320275 -0.464618

# %% [markdown]
# along Row

# %%
df3=pd.concat([df1,df2],axis=1,join="inner",ignore_index=True)
df3
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.626788  1.565946 -0.252991 -0.131553 -1.578725  0.544465 -0.086178
# 1 -0.466376 -0.744839 -0.409002 -0.704478 -0.708386 -1.331185  0.556176
# 2  1.434732  0.799465 -0.209512  0.594617  0.528272  1.408658  1.161387
# 3 -0.589754  0.029569 -1.314295  1.194373  1.295154 -0.133570  0.261933
# 4  0.608282  1.125297  0.669932 -0.192409  1.088963  1.194254  0.125874
#
#           7         8
# 0 -0.884574  0.962751
# 1  1.441838  1.739134
# 2  0.980376 -0.623762
# 3  1.387955  0.285104
# 4 -0.320275 -0.464618

# %% [markdown]
# 3.7 Concatenate data frames using join = 'outer' (union)

# %% [markdown]
# join = 'outer' and axis = 0 (union of dataframe columnwise)

# %%
df3=pd.concat([df1,df2],axis=0)
print(df3)
df3=pd.concat([df1,df2],axis=0,join='outer')
print(df3)
# Out:
#           0         1         2         3         4
# 0 -0.626788  1.565946 -0.252991 -0.131553 -1.578725
# 1 -0.466376 -0.744839 -0.409002 -0.704478 -0.708386
# 2  1.434732  0.799465 -0.209512  0.594617  0.528272
# 3 -0.589754  0.029569 -1.314295  1.194373  1.295154
# 4  0.608282  1.125297  0.669932 -0.192409  1.088963
# 5  0.097562  0.973448 -0.501081 -2.382428  0.143134
# 0  0.544465 -0.086178 -0.884574  0.962751       NaN
# 1 -1.331185  0.556176  1.441838  1.739134       NaN
# 2  1.408658  1.161387  0.980376 -0.623762       NaN
# 3 -0.133570  0.261933  1.387955  0.285104       NaN
# 4  1.194254  0.125874 -0.320275 -0.464618       NaN
#           0         1         2         3         4
# 0 -0.626788  1.565946 -0.252991 -0.131553 -1.578725
# 1 -0.466376 -0.744839 -0.409002 -0.704478 -0.708386
# 2  1.434732  0.799465 -0.209512  0.594617  0.528272
# 3 -0.589754  0.029569 -1.314295  1.194373  1.295154
# 4  0.608282  1.125297  0.669932 -0.192409  1.088963
# 5  0.097562  0.973448 -0.501081 -2.382428  0.143134
# 0  0.544465 -0.086178 -0.884574  0.962751       NaN
# 1 -1.331185  0.556176  1.441838  1.739134       NaN
# 2  1.408658  1.161387  0.980376 -0.623762       NaN
# 3 -0.133570  0.261933  1.387955  0.285104       NaN
# 4  1.194254  0.125874 -0.320275 -0.464618       NaN

# %% [markdown]
# join = 'outer' and axis = 1 (union of dataframe row wise; using index)

# %%
df3=pd.concat([df1,df2],axis=1,join="outer")
df3
# Out:
#           0         1         2         3         4         0         1  \
# 0 -0.626788  1.565946 -0.252991 -0.131553 -1.578725  0.544465 -0.086178
# 1 -0.466376 -0.744839 -0.409002 -0.704478 -0.708386 -1.331185  0.556176
# 2  1.434732  0.799465 -0.209512  0.594617  0.528272  1.408658  1.161387
# 3 -0.589754  0.029569 -1.314295  1.194373  1.295154 -0.133570  0.261933
# 4  0.608282  1.125297  0.669932 -0.192409  1.088963  1.194254  0.125874
# 5  0.097562  0.973448 -0.501081 -2.382428  0.143134       NaN       NaN
#
#           2         3
# 0 -0.884574  0.962751
# 1  1.441838  1.739134
# 2  0.980376 -0.623762
# 3  1.387955  0.285104
# 4 -0.320275 -0.464618
# 5       NaN       NaN

# %% [markdown]
# 3.8 Merge 1: Merging a dataframe with one unique key combination

# %%
import pandas as pd

# Define a dictionary containing employee data
df1 = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],})
df1

df2 = pd.DataFrame({'Key': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']})
df2
# Out:
#   Key    Address Qualification
# 0  K0     Nagpur         Btech
# 1  K1     Kanpur           B.A
# 2  K2  Allahabad          Bcom
# 3  K3    Kannuaj        B.hons

# %% [markdown]
# Merge with one unique key combination

# %%
df3 = pd.merge(df1, df2, on='Key')
df3
# Out:
#   Key    Name  Age    Address Qualification
# 0  K0     Jai   27     Nagpur         Btech
# 1  K1  Princi   24     Kanpur           B.A
# 2  K2  Gaurav   22  Allahabad          Bcom
# 3  K3    Anuj   32    Kannuaj        B.hons

# %% [markdown]
# 3.9 Merge 2: Merging dataframe using multiple join keys

# %%
df1 = pd.DataFrame({'Key1': ['K0', 'K1', 'K2', 'K3'],
         'Key2': ['K0', 'K1', 'K0', 'K1'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],})
df1

df2 = pd.DataFrame({'Key1': ['K0', 'K1', 'K2', 'K3'],
         'Key2': ['K0', 'K0', 'K0', 'K0'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['BTech', 'BA', 'BCom', 'BE']})
df2
# Out:
#   Key1 Key2    Address Qualification
# 0   K0   K0     Nagpur         BTech
# 1   K1   K0     Kanpur            BA
# 2   K2   K0  Allahabad          BCom
# 3   K3   K0    Kannuaj            BE

# %%
df3=pd.merge(df1,df2,on=['Key1', 'Key2'])
df3
# Out:
#   Key1 Key2    Name  Age    Address Qualification
# 0   K0   K0     Jai   27     Nagpur         BTech
# 1   K2   K0  Gaurav   22  Allahabad          BCom

# %% [markdown]
# **4. Working with Date**

# %% [markdown]
# 4.2 Generate dates within range

# %%
dates=pd.date_range(start='20030101',end='20030107')
dates
# Out:
# DatetimeIndex(['2003-01-01', '2003-01-02', '2003-01-03', '2003-01-04',
#                '2003-01-05', '2003-01-06', '2003-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# 4.2 Generate dates for particular period

# %%
dates=pd.date_range(start='230101',periods=6)
dates
# Out:
# DatetimeIndex(['2001-01-23', '2001-01-24', '2001-01-25', '2001-01-26',
#                '2001-01-27', '2001-01-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates=pd.date_range(end="230101",periods=6)
dates
# Out:
# DatetimeIndex(['2001-01-18', '2001-01-19', '2001-01-20', '2001-01-21',
#                '2001-01-22', '2001-01-23'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# 4.4 Generate dates with days frequency with multiple GAP

# %%
dates=pd.date_range(start="230101",end="300101",freq='2D')#D is for days
print(dates)
dates=pd.date_range(start="230101",end='230701',freq="2M")#M for months
print(dates)
# Out:
# DatetimeIndex(['2001-01-23', '2001-01-25', '2001-01-27', '2001-01-29'], dtype='datetime64[ns]', freq='2D')
# DatetimeIndex(['2001-01-31', '2001-03-31', '2001-05-31'], dtype='datetime64[ns]', freq='2ME')
# <ipython-input-74-1781004868>:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates=pd.date_range(start="230101",end='230701',freq="2M")#M for months
